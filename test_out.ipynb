# %%
a = 1.0000000000
b = 2.0000000000
print("7f",a+b)
# Out:
# 7f 3.0

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]]) #this is a nested list
print(arr[0][0])
# Out:
# 1

# %%
a = 10

# %%
a
# Out:
# 10

# %%
import PIL.Image
import numpy as np

# %%
import PIL.Image
import numpy as np

# %%
img = PIL.Image.open("_103330503_musk3.jpg")
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x432 at 0x25DFF9571F0>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x432>

# %%
img_array = np.array(img)

# %%
img_array
# Out:
# array([[[  7,  11,  10],
#         [  6,  10,   9],
#         [  8,  10,   9],
#         ...,
#         [137, 125, 129],
#         [140, 128, 132],
#         [143, 131, 135]],
#
#        [[  7,  11,  10],
#         [  6,  10,   9],
#         [  8,  10,   9],
#         ...,
#         [135, 123, 127],
#         [137, 125, 129],
#         [140, 128, 132]],
#
#        [[  8,  10,   9],
#         [  8,  10,   9],
#         [  8,  10,   9],
#         ...,
#         [133, 121, 125],
#         [134, 122, 126],
#         [136, 124, 128]],
#
#        ...,
#
#        [[ 37,  26,  30],
#         [ 37,  26,  30],
#         [ 39,  27,  31],
#         ...,
#         [ 45,  36,  41],
#         [ 43,  34,  39],
#         [ 42,  33,  38]],
#
#        [[ 37,  26,  30],
#         [ 36,  25,  29],
#         [ 39,  27,  31],
#         ...,
#         [ 45,  36,  41],
#         [ 43,  34,  39],
#         [ 42,  33,  38]],
#
#        [[ 37,  26,  30],
#         [ 36,  25,  29],
#         [ 38,  26,  30],
# ...

# %%
img = PIL.Image.open("A_black_image.jpg")

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=640x480>

# %%
img_array = np.array(img)

# %%
print(img_array)
# Out:
# [[[ 3  3  3]
#   [ 3  3  3]
#   [ 3  3  3]
#   ...
#   [ 5  5  3]
#   [ 3  4  1]
#   [ 3  4  1]]
#
#  [[ 3  3  3]
#   [ 3  3  3]
#   [ 3  3  3]
#   ...
#   [ 3  4  1]
#   [ 6  6  4]
#   [ 8  9  6]]
#
#  [[ 3  3  3]
#   [ 3  3  3]
#   [ 3  3  3]
#   ...
#   [ 6  6  4]
#   [ 3  4  1]
#   [ 1  2  0]]
#
#  ...
#
#  [[ 5  5  3]
#   [ 5  5  3]
#   [ 5  5  3]
#   ...
#   [10  8  6]
#   [13 11 10]
#   [ 7  5  4]]
#
#  [[ 5  5  3]
#   [ 5  5  3]
#   [ 5  5  3]
#   ...
#   [ 7  5  4]
#   [10  8  6]
#   [10  8  6]]
#
#  [[ 5  5  3]
#   [ 5  5  3]
#   [ 5  5  3]
#   ...
#   [ 6  4  3]
#   [ 9  7  5]
#   [12 10  8]]]
