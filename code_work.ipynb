# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
import keras

# %%
from PIL import Image

# %%
import glob

# %%
train_files = glob.glob("C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train/*")

# %%
train_files
# Out:
# ['C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\00048bba-979b-4f84-b833-5bbbb082b582_0L.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\000547a2-d456-4b16-b351-12ca9b40e390_0L.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\000cac8e-fcf0-4f8c-bd16-c257d1e6d7a8_2L.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\000d9961-8136-4dee-9820-86e178777958_0L.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\0010095b-2e3d-4517-a511-1f688c378f96_5L.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\00147c9a-67f5-4e86-a56b-681f0815ef2b_5R.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\0014eacf-b0b7-49af-9d67-83661b3debb4_2R.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\001cddc6-e29c-44da-82d5-bd00ec215f07_2R.png',
#  'C:/Users/Rohan/OneDrive/Desktop/is_the_road_safe/Work/train\\001e18d6-4632-4876-a922-7b4ead742070_3L.png',
# ...

# %%
img=Image.open(train_files[0])
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=128x128>
